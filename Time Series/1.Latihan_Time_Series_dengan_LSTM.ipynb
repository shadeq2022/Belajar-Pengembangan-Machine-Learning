# %% [markdown]
# <a href="https://colab.research.google.com/github/shadeq2022/Belajar-Pengembangan-Machine-Learning/blob/main/Time%20Series/1.Latihan_Time_Series_dengan_LSTM.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Latihan Time Series dengan LSTM

# %%
import numpy as np
import pandas as pd
from keras.layers import Dense, LSTM
import matplotlib.pyplot as plt
import tensorflow as tf

# %% [markdown]
# Ubah dataset menjadi dataframe dengan fungsi read_csv(). Lalu menampilkan 5 data teratas pada dataframe menggunakan fungsi head().

# %%
data_train = pd.read_csv('DailyDelhiClimateTrain.csv')
data_train.head()
# Out:
#          date   meantemp   humidity  wind_speed  meanpressure
# 0  2013-01-01  10.000000  84.500000    0.000000   1015.666667
# 1  2013-01-02   7.400000  92.000000    2.980000   1017.800000
# 2  2013-01-03   7.166667  87.000000    4.633333   1018.666667
# 3  2013-01-04   8.666667  71.333333    1.233333   1017.166667
# 4  2013-01-05   6.000000  86.833333    3.700000   1016.500000

# %% [markdown]
# Cek apakah ada nilai yang hilang dari dataset menggunakan fungsi isnull().

# %%
data_train.isnull().sum()
# Out:
# date            0
# meantemp        0
# humidity        0
# wind_speed      0
# meanpressure    0
# dtype: int64
